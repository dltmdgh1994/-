# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/train'
validation_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/valid'

batch_size = 1000
img_size = 32

# train_datagen = ImageDataGenerator(rescale=1/255)

train_datagen = ImageDataGenerator(rescale=1/255,
                                   rotation_range=20,  # 지정된 각도 범위내에서 임의로 원본 이미지를 회전
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,    #  1-수치 혹은 1+수치만큼 확대 및 축소
                                   )



validation_datagen = ImageDataGenerator(rescale=1/255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_size,img_size),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(img_size,img_size),                       
    batch_size=batch_size,    
    class_mode='categorical'                    
)
# Out:
# Found 54332 images belonging to 2 classes.
# Found 13585 images belonging to 2 classes.

# %% [markdown]
# # Model Train

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam, Nadam

# gpu 메모리 최대로 잡는 것을 방지
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

# 모델 구축

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same',
                 activation='relu',
                 input_shape=(img_size, img_size, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(4096, activation='relu', kernel_initializer='he_normal'))
#model.add(Dropout(0.5))
model.add(Dense(2048, activation='relu', kernel_initializer='he_normal'))
#model.add(Dropout(0.5))
model.add(Dense(1024, activation='relu', kernel_initializer='he_normal'))

model.add(Dense(2, activation='softmax'))

model.summary()

model.compile(optimizer=Nadam(learning_rate=1e-5), loss='categorical_crossentropy',
                metrics=['accuracy'])
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 44,345,666
# Trainable params: 44,345,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(patience = 15) # 조기종료 콜백함수 정의

# 데이터 개수 / batch_size
steps_per_epoch = 54332 / batch_size
val_steps = 13585 / batch_size

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=200,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/200
#  2/54 [>.............................] - ETA: 3s - loss: 0.6929 - accuracy: 0.4550WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0330s vs `on_train_batch_end` time: 0.0861s). Check your callbacks.
# 55/54 [==============================] - 52s 946ms/step - loss: 0.6579 - accuracy: 0.5985 - val_loss: 0.5690 - val_accuracy: 0.6911
# Epoch 2/200
# 55/54 [==============================] - 33s 604ms/step - loss: 0.5196 - accuracy: 0.7772 - val_loss: 0.4129 - val_accuracy: 0.8384
# Epoch 3/200
# 55/54 [==============================] - 33s 603ms/step - loss: 0.4523 - accuracy: 0.8055 - val_loss: 0.3640 - val_accuracy: 0.8568
# Epoch 4/200
# 55/54 [==============================] - 33s 597ms/step - loss: 0.4194 - accuracy: 0.8201 - val_loss: 0.3478 - val_accuracy: 0.8657
# Epoch 5/200
# 55/54 [==============================] - 33s 598ms/step - loss: 0.3949 - accuracy: 0.8311 - val_loss: 0.3115 - val_accuracy: 0.8820
# Epoch 6/200
# 55/54 [==============================] - 33s 596ms/step - loss: 0.3731 - accuracy: 0.8429 - val_loss: 0.2925 - val_accuracy: 0.8824
# Epoch 7/200
# 55/54 [==============================] - 33s 599ms/step - loss: 0.3574 - accuracy: 0.8503 - val_loss: 0.2623 - val_accuracy: 0.9029
# Epoch 8/200
# 55/54 [==============================] - 33s 598ms/step - loss: 0.3449 - accuracy: 0.8558 - val_loss: 0.2490 - val_accuracy: 0.9121
# Epoch 9/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0
200
# 55/54 [==============================] - 33s 593ms/step - loss: 0.0724 - accuracy: 0.9736 - val_loss: 0.0534 - val_accuracy: 0.9792
# Epoch 61/200
# 55/54 [==============================] - 33s 593ms/step - loss: 0.0717 - accuracy: 0.9741 - val_loss: 0.0535 - val_accuracy: 0.9802
# Epoch 62/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0680 - accuracy: 0.9750 - val_loss: 0.0528 - val_accuracy: 0.9797
# Epoch 63/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0699 - accuracy: 0.9745 - val_loss: 0.0520 - val_accuracy: 0.9810
# Epoch 64/200
# 55/54 [==============================] - 33s 593ms/step - loss: 0.0716 - accuracy: 0.9736 - val_loss: 0.0554 - val_accuracy: 0.9809
# Epoch 65/200
# 55/54 [==============================] - 33s 596ms/step - loss: 0.0674 - accuracy: 0.9757 - val_loss: 0.0516 - val_accuracy: 0.9808
# Epoch 66/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0682 - accuracy: 0.9753 - val_loss: 0.0505 - val_accuracy: 0.9807
# Epoch 67/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0675 - accuracy: 0.9757 - val_loss: 0.0590 - val_accuracy: 0.9789
# Epoch 68/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0687 - accuracy: 0.9748 - val_loss: 0.0501 - val_accuracy: 0.9811
# Epoch 69/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0647 - accuracy: 0.9763 - val_loss: 0.0510 - val_accuracy: 0.9801
# Epoch 70/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0660 - accuracy: 0.9759 - val_loss: 0.0496 - val_accuracy: 0.9817
# Epoch 71/200
# 55/54 [==============================] - 33s 596ms/step - loss: 0.0620 - accuracy: 0.9772 - val_loss: 0.0483 - val_accuracy: 0.9817
# Epoch 72/200
# 55/54 [==============================] - 33s 593ms/step - loss: 0.0632 - accuracy: 0.9771 - val_loss: 0.0498 - val_accuracy: 0.9813
# Epoch 73/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0638 - accuracy: 0.9766 - val_loss: 0.0502 - val_accuracy: 0.9822
# Epoch 74/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0603 - accuracy: 0.9776 - val_loss: 0.0478 - val_accuracy: 0.9819
# Epoch 75/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0656 - accuracy: 0.9760 - val_loss: 0.0490 - val_accuracy: 0.9822
# Epoch 76/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0610 - accuracy: 0.9782 - val_loss: 0.0466 - val_accuracy: 0.9822
# Epoch 77/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0635 - accuracy: 0.9763 - val_loss: 0.0469 - val_accuracy: 0.9825
# Epoch 78/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0591 - accuracy: 0.9783 - val_loss: 0.0488 - val_accuracy: 0.9806
# Epoch 79/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0592 - accuracy: 0.9780 - val_loss: 0.0551 - val_accuracy: 0.9822
# Epoch 80/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0592 - accuracy: 0.9782 - val_loss: 0.0512 - val_accuracy: 0.9796
# Epoch 81/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0574 - accuracy: 0.9789 - val_loss: 0.0461 - val_accuracy: 0.9814
# Epoch 82/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0567 - accuracy: 0.9790 - val_loss: 0.0463 - val_accuracy: 0.9833
# Epoch 83/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0575 - accuracy: 0.9785 - val_loss: 0.0464 - val_accuracy: 0.9837
# Epoch 84/200
# 55/54 [==============================] - 33s 592ms/step - loss: 0.0573 - accuracy: 0.9789 - val_loss: 0.0447 - val_accuracy: 0.9836
# Epoch 85/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0574 - accuracy: 0.9785 - val_loss: 0.0453 - val_accuracy: 0.9834
# Epoch 86/200
# 55/54 [==============================] - 33s 595ms/step - loss: 0.0571 - accuracy: 0.9786 - val_loss: 0.0475 - val_accuracy: 0.9815
# Epoch 87/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.0563 - accuracy: 0.9793 - val_loss: 0.0444 - val_accuracy: 0.9837
# Epoch 88/200
# 55/54 [==============================] - 33s 594ms/step - loss: 0.
200
# 55/54 [==============================] - 33s 601ms/step - loss: 0.0389 - accuracy: 0.9858 - val_loss: 0.0376 - val_accuracy: 0.9865
# Epoch 143/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.0403 - val_accuracy: 0.9852
# Epoch 144/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0378 - accuracy: 0.9862 - val_loss: 0.0537 - val_accuracy: 0.9799
# Epoch 145/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0393 - accuracy: 0.9853 - val_loss: 0.0378 - val_accuracy: 0.9861
# Epoch 146/200
# 55/54 [==============================] - 33s 601ms/step - loss: 0.0375 - accuracy: 0.9859 - val_loss: 0.0379 - val_accuracy: 0.9866
# Epoch 147/200
# 55/54 [==============================] - 33s 599ms/step - loss: 0.0398 - accuracy: 0.9854 - val_loss: 0.0367 - val_accuracy: 0.9868
# Epoch 148/200
# 55/54 [==============================] - 33s 599ms/step - loss: 0.0376 - accuracy: 0.9864 - val_loss: 0.0357 - val_accuracy: 0.9875
# Epoch 149/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0382 - accuracy: 0.9860 - val_loss: 0.0358 - val_accuracy: 0.9871
# Epoch 150/200
# 55/54 [==============================] - 33s 602ms/step - loss: 0.0362 - accuracy: 0.9867 - val_loss: 0.0379 - val_accuracy: 0.9867
# Epoch 151/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0369 - accuracy: 0.9864 - val_loss: 0.0376 - val_accuracy: 0.9869
# Epoch 152/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0366 - accuracy: 0.9861 - val_loss: 0.0359 - val_accuracy: 0.9868
# Epoch 153/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0362 - accuracy: 0.9870 - val_loss: 0.0374 - val_accuracy: 0.9860
# Epoch 154/200
# 55/54 [==============================] - 33s 602ms/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.0381 - val_accuracy: 0.9869
# Epoch 155/200
# 55/54 [==============================] - 33s 602ms/step - loss: 0.0374 - accuracy: 0.9863 - val_loss: 0.0368 - val_accuracy: 0.9868
# Epoch 156/200
# 55/54 [==============================] - 33s 602ms/step - loss: 0.0358 - accuracy: 0.9863 - val_loss: 0.0376 - val_accuracy: 0.9870
# Epoch 157/200
# 55/54 [==============================] - 33s 601ms/step - loss: 0.0357 - accuracy: 0.9867 - val_loss: 0.0362 - val_accuracy: 0.9873
# Epoch 158/200
# 55/54 [==============================] - 33s 602ms/step - loss: 0.0364 - accuracy: 0.9866 - val_loss: 0.0362 - val_accuracy: 0.9873
# Epoch 159/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0350 - accuracy: 0.9866 - val_loss: 0.0368 - val_accuracy: 0.9872
# Epoch 160/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0356 - accuracy: 0.9873 - val_loss: 0.0375 - val_accuracy: 0.9870
# Epoch 161/200
# 55/54 [==============================] - 33s 601ms/step - loss: 0.0357 - accuracy: 0.9866 - val_loss: 0.0365 - val_accuracy: 0.9868
# Epoch 162/200
# 55/54 [==============================] - 33s 601ms/step - loss: 0.0347 - accuracy: 0.9869 - val_loss: 0.0423 - val_accuracy: 0.9854
# Epoch 163/200
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0350 - accuracy: 0.9871 - val_loss: 0.0388 - val_accuracy: 0.9868

# %%
import matplotlib.pyplot as plt

# 학습 곡선을 나타내는 함수
def plot_loss_curve(history):
    plt.figure(figsize=(10, 7))

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train loss=", history.history['loss'][-1])
    print("validation loss=", history.history['val_loss'][-1])
    
def plot_acc_curve(history):
    plt.figure(figsize=(10, 7))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train accuracy=", history.history['accuracy'][-1])
    print("validation accuracy=", history.history['val_accuracy'][-1])
    
plot_loss_curve(history)
plot_acc_curve(history)
# Out:
# train loss= 0.035026997327804565
# validation loss= 0.038790296763181686
# train accuracy= 0.9870978593826294
# validation accuracy= 0.986750066280365

# %%
model.save('C:/Users/s_csmscox/jupyterSave/eye_blink/eye_blink_CNN_ImgGen2.h5')

# %% [markdown]
# # Model Test

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/test'

batch_size = 50
img_size = 32

test_datagen = ImageDataGenerator(rescale=1/255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size,img_size),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)
# Out:
# Found 16981 images belonging to 2 classes.

# %%
# 모델 평가

steps = 16981 / batch_size

print("-- Evaluate --")
scores = model.evaluate(test_generator, steps=steps)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# 340/339 [==============================] - 10s 30ms/step - loss: 0.0363 - accuracy: 0.9870
# accuracy: 98.70%

# %% [markdown]
# # Fine Tuning

# %%
from tensorflow.keras.models import load_model
import tensorflow as tf

# gpu 메모리 최대로 잡는 것을 방지
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)

model = load_model('C:/Users/s_csmscox/jupyterSave/eye_blink/eye_blink_CNN_imgGen2.h5')
model.summary()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              8390656
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 2050
# =================================================================
# Total params: 44,345,666
# Trainable params: 44,345,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Nadam

early_stopping = EarlyStopping(patience = 15) # 조기종료 콜백함수 정의

# 데이터 개수 / batch_size
steps_per_epoch = 54332 / batch_size
val_steps = 13585 / batch_size

model.compile(optimizer=Nadam(learning_rate=1e-7), loss='categorical_crossentropy',
                metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=steps_per_epoch,
                    epochs=100,
                    validation_data=validation_generator,
                    validation_steps=val_steps,
                    callbacks=[early_stopping],
                    verbose=1
                    )
# Out:
# Epoch 1/100
#  2/54 [>.............................] - ETA: 3s - loss: 0.0291 - accuracy: 0.9910WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0310s vs `on_train_batch_end` time: 0.0841s). Check your callbacks.
# 55/54 [==============================] - 33s 609ms/step - loss: 0.0355 - accuracy: 0.9872 - val_loss: 0.0359 - val_accuracy: 0.9875
# Epoch 2/100
# 55/54 [==============================] - 33s 604ms/step - loss: 0.0330 - accuracy: 0.9874 - val_loss: 0.0358 - val_accuracy: 0.9876
# Epoch 3/100
# 55/54 [==============================] - 33s 605ms/step - loss: 0.0330 - accuracy: 0.9881 - val_loss: 0.0357 - val_accuracy: 0.9875
# Epoch 4/100
# 55/54 [==============================] - 33s 604ms/step - loss: 0.0318 - accuracy: 0.9885 - val_loss: 0.0356 - val_accuracy: 0.9874
# Epoch 5/100
# 55/54 [==============================] - 33s 605ms/step - loss: 0.0329 - accuracy: 0.9876 - val_loss: 0.0356 - val_accuracy: 0.9873
# Epoch 6/100
# 55/54 [==============================] - 33s 603ms/step - loss: 0.0323 - accuracy: 0.9878 - val_loss: 0.0356 - val_accuracy: 0.9873
# Epoch 7/100
# 55/54 [==============================] - 33s 605ms/step - loss: 0.0321 - accuracy: 0.9884 - val_loss: 0.0355 - val_accuracy: 0.9873
# Epoch 8/100
# 55/54 [==============================] - 35s 627ms/step - loss: 0.0327 - accuracy: 0.9878 - val_loss: 0.0355 - val_accuracy: 0.9873
# Epoch 9/100
# 55/54 [==============================] - 35s 636ms/step - loss: 0.0326 - accuracy: 0.9879 - val_loss: 0.0355 - val_accuracy: 0.9873
# Epoch 10/100
# 55/54 [==============================] - 33s 603ms/step - loss: 0.0325 - accuracy: 0.9883 - val_loss: 0.0355 - val_accuracy: 0.9873
# Epoch 11/100
# 55/54 [==============================] - 33s 603ms/step - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.0354 - val_accuracy: 0.9875
# Epoch 12/100
# 55/54 [==============================] - 33s 600ms/step - loss: 0.0322 - accuracy: 0.9876 - val_loss: 0.0354 - val_accuracy: 0.9875
# Epoch 13/100
# 55/54 [==============================] - 33s 604ms/step - loss: 0.0326 - accuracy: 0.9880 - val_loss: 0.0354 - val_accuracy: 0.9874
# Epoch 14/100
# 55/54 [==============================] - 33s 606ms/step - loss: 0.0321 - accuracy: 0.9882 - val_loss: 0.0353 - val_accuracy: 0.9875
# Epoch 15/100
# 55/54 [==============================] - 35s 628ms/step - loss: 0.0319 - accuracy: 0.9884 - val_loss: 0.0354 - val_accuracy: 0.9874
# Epoch 16/100
# 55/54 [==============================] - 35s 629ms/step - loss: 0.0325 - accuracy: 0.9878 - val_loss: 0.0353 - val_accuracy: 0.9874
# Epoch 17/100
# 55/54 [==============================] - 35s 629ms/step - loss: 0.0325 - accuracy: 0.9880 - val_loss: 0.0353 - val_accuracy: 0.9874
# Epoch 18/100
# 55/54 [==============================] - 35s 627ms/step - loss: 0.0334 - accuracy: 0.9876 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 19/100
# 55/54 [==============================] - 35s 628ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.0353 - val_accuracy: 0.9875
# Epoch 20/100
# 55/54 [==============================] - 35s 630ms/step - loss: 0.0320 - accuracy: 0.9881 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 21/100
# 55/54 [==============================] - 34s 624ms/step - loss: 0.0326 - accuracy: 0.9886 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 22/100
# 55/54 [==============================] - 35s 628ms/step - loss: 0.0321 - accuracy: 0.9881 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 23/100
# 55/54 [==============================] - 34s 622ms/step - loss: 0.0324 - accuracy: 0.9879 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 24/100
# 55/54 [==============================] - 34s 616ms/step - loss: 0.0324 - accuracy: 0.9884 - val_loss: 0.0352 - val_accuracy: 0.9875
# Epoch 25/100
# 55/54 [==============================] - 34s 618ms/step - loss: 0.0326 - accuracy: 0.9880 - val_loss: 0.0352 - val_accuracy: 0.9874
# Epoch 26/100
# 55/54 [==============================] - 34s 609ms/step - loss: 0.0321 - accuracy: 0.9883 - val_loss: 0.0352 - val_accuracy: 0.9876
# Epoch 27/100
# 55/54 [==============================] - 33s 605ms/step - loss: 0.0333 - accuracy: 0.9881 - val_loss: 0.0352 - val_accuracy: 0.9875
# Epoch 28/100
# 55/54 [==============================] - 33s 609ms/step - loss: 0.0322 - accuracy: 0.9879 - val_loss: 0.0352 - val_accuracy: 0.9874
# Epoch 29/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0322 - accuracy: 0.9881 - val_loss: 0.0353 - val_accuracy: 0.9873
# Epoch 30/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0320 - accuracy: 0.9880 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 31/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0321 - accuracy: 0.9885 - val_loss: 0.0352 - val_accuracy: 0.9876
# Epoch 32/100
# 55/54 [==============================] - 33s 608ms/step - loss: 0.0323 - accuracy: 0.9881 - val_loss: 0.0352 - val_accuracy: 0.9874
# Epoch 33/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.0352 - val_accuracy: 0.9874
# Epoch 34/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0324 - accuracy: 0.9884 - val_loss: 0.0352 - val_accuracy: 0.9874
# Epoch 35/100
# 55/54 [==============================] - 33s 606ms/step - loss: 0.0329 - accuracy: 0.9879 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 36/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0315 - accuracy: 0.9883 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 37/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.0352 - val_accuracy: 0.9875
# Epoch 38/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0325 - accuracy: 0.9881 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 39/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 40/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.0352 - val_accuracy: 0.9876
# Epoch 41/100
# 55/54 [==============================] - 34s 609ms/step - loss: 0.0322 - accuracy: 0.9880 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 42/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0322 - accuracy: 0.9880 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 43/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0317 - accuracy: 0.9886 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 44/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 45/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0319 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 46/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0316 - accuracy: 0.9880 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 47/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0316 - accuracy: 0.9886 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 48/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.0352 - val_accuracy: 0.9873
# Epoch 49/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0324 - accuracy: 0.9881 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 50/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 51/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0320 - accuracy: 0.9886 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 52/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0323 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 53/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0314 - accuracy: 0.9880 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 54/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0314 - accuracy: 0.9885 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 55/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0315 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 56/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0321 - accuracy: 0.9880 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 57/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0312 - accuracy: 0.9890 - val_loss: 0.0351 - val_accuracy: 0.9872
# Epoch 58/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 59/100
# 55/54 [==============================] - 33s 608ms/step - loss: 0.0318 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9872
# Epoch 60/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 61/100
# 55/54 [==============================] - 34s 615ms/step - loss: 0.0326 - accuracy: 0.9881 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 62/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0336 - accuracy: 0.9873 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 63/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 64/100
# 55/54 [==============================] - 33s 608ms/step - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 65/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0317 - accuracy: 0.9883 - val_loss: 0.0350 - val_accuracy: 0.9877
# Epoch 66/100
# 55/54 [==============================] - 34s 614ms/step - loss: 0.0330 - accuracy: 0.9877 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 67/100
# 55/54 [==============================] - 33s 608ms/step - loss: 0.0319 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 68/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0329 - accuracy: 0.9881 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 69/100
# 55/54 [==============================] - 34s 609ms/step - loss: 0.0323 - accuracy: 0.9880 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 70/100
# 55/54 [==============================] - 34s 614ms/step - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 71/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0315 - accuracy: 0.9886 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 72/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0313 - accuracy: 0.9886 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 73/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0313 - accuracy: 0.9888 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 74/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0317 - accuracy: 0.9879 - val_loss: 0.0351 - val_accuracy: 0.9875
# Epoch 75/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0322 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 76/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0316 - accuracy: 0.9883 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 77/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0327 - accuracy: 0.9881 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 78/100
# 55/54 [==============================] - 34s 614ms/step - loss: 0.0316 - accuracy: 0.9888 - val_loss: 0.0350 - val_accuracy: 0.9878
# Epoch 79/100
# 55/54 [==============================] - 33s 607ms/step - loss: 0.0312 - accuracy: 0.9885 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 80/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0320 - accuracy: 0.9885 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 81/100
# 55/54 [==============================] - 33s 609ms/step - loss: 0.0317 - accuracy: 0.9887 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 82/100
# 55/54 [==============================] - 34s 612ms/step - loss: 0.0317 - accuracy: 0.9880 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 83/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 84/100
# 55/54 [==============================] - 34s 610ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 85/100
# 55/54 [==============================] - 33s 608ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 0.0351 - val_accuracy: 0.9876
# Epoch 86/100
# 55/54 [==============================] - 33s 609ms/step - loss: 0.0316 - accuracy: 0.9883 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 87/100
# 55/54 [==============================] - 34s 614ms/step - loss: 0.0325 - accuracy: 0.9877 - val_loss: 0.0350 - val_accuracy: 0.9872
# Epoch 88/100
# 55/54 [==============================] - 34s 615ms/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9874
# Epoch 89/100
# 55/54 [==============================] - 34s 613ms/step - loss: 0.0320 - accuracy: 0.9882 - val_loss: 0.0351 - val_accuracy: 0.9873
# Epoch 90/100
# 55/54 [==============================] - 34s 614ms/step - loss: 0.0316 - accuracy: 0.9886 - val_loss: 0.0350 - val_accuracy: 0.9875
# Epoch 91/100
# 55/54 [==============================] - 34s 611ms/step - loss: 0.0320 - accuracy: 0.9884 - val_loss: 0.0350 - val_accuracy: 0.9873
# Epoch 92/100
# 35/54 [==================>...........] - ETA: 10s - loss: 0.0316 - accuracy: 0.9886
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-87d747e48eb1> in <module>
#      11                 metrics=['accuracy'])
#      12
# ---> 13 history = model.fit(train_generator,
#      14                     steps_per_epoch=steps_per_epoch,
#      15                     epochs=100,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

# 학습 곡선을 나타내는 함수
def plot_loss_curve(history):
    plt.figure(figsize=(10, 7))

    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train loss=", history.history['loss'][-1])
    print("validation loss=", history.history['val_loss'][-1])
    
def plot_acc_curve(history):
    plt.figure(figsize=(10, 7))

    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper right')
    plt.show()   
    
    print("train accuracy=", history.history['accuracy'][-1])
    print("validation accuracy=", history.history['val_accuracy'][-1])
    
plot_loss_curve(history)
plot_acc_curve(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e96d5a92f24b> in <module>
#      30     print("validation accuracy=", history.history['val_accuracy'][-1])
#      31
# ---> 32 plot_loss_curve(history)
#      33 plot_acc_curve(history)
#
# NameError: name 'history' is not defined

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

test_dir = 'C:/Users/s_csmscox/jupyterSave/eye_blink/test'

batch_size = 50
img_size = 32

test_datagen = ImageDataGenerator(rescale=1/255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_size,img_size),                      
    batch_size=batch_size,     
    class_mode='categorical'                    
)
# Out:
# Found 16981 images belonging to 2 classes.

# %%
# 모델 평가

steps = 16981 / batch_size

print("-- Evaluate --")
scores = model.evaluate(test_generator, steps=steps)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# -- Evaluate --
# 340/339 [==============================] - 5s 15ms/step - loss: 0.0297 - accuracy: 0.9897
# accuracy: 98.97%

# %%
model.save('C:/Users/s_csmscox/jupyterSave/eye_blink/eye_blink_CNN_ImgGen1_FT.h5')
